# %% [markdown]
# Importing usefull libraries to perform operations

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Reading csv file

# %%
data=pd.read_csv("honda_car_selling.csv")

# %% [markdown]
# Printing all the values

# %%
print(data.head()) # first 5 data of the dataset
print(data.tail()) # last 5 data of the dataset
print(data.shape) # printing the number of size and column
print(data.columns) # printing title of all the columns
# Out:
#    Year  kms Driven Fuel Type Suspension  Price                  Car Model
# 0  2015  81506 kms       CNG      Manual   4.21  Honda Amaze S Plus i-VTEC
# 1  2019  23561 kms    Diesel      Manual  11.00     Honda BR-V i-DTEC V MT
# 2  2014  27961 kms    Diesel      Manual   4.22      Honda Amaze S i-Dtech
# 3  2021  28183 kms    Diesel      Manual   8.50       Honda Amaze S Diesel
# 4  2015  28451 kms    Diesel      Manual   7.00       Honda City i DTEC VX
#      Year    kms Driven Fuel Type  Suspension  Price  \
# 994  2009   130135 kms    Petrol    Automatic   2.50
# 995  2015   133745 kms    Petrol    Automatic   4.40
# 996  2010   133878 kms    Petrol    Automatic   2.77
# 997  2012   145956 kms    Petrol    Automatic   3.65
# 998  2015  1100000 kms    Petrol    Automatic  10.75
#
#                      Car Model
# 994        Honda City 1.5 S AT
# 995  Honda Amaze VX AT i-Vtech
# 996        Honda City 1.5 V AT
# 997  Honda City 1.5 V AT Sunro
# 998      Honda CR-V Petrol 2WD
# ...

# %%
data['kms Driven']=data['kms Driven'].str.replace('kms ','')
data['kms Driven']=data['kms Driven'].astype(int)

data['Price']=data['Price'].astype(int)
print(data.head())
# Out:
#    Year  kms Driven Fuel Type Suspension  Price                  Car Model
# 0  2015       81506      CNG      Manual      4  Honda Amaze S Plus i-VTEC
# 1  2019       23561   Diesel      Manual     11     Honda BR-V i-DTEC V MT
# 2  2014       27961   Diesel      Manual      4      Honda Amaze S i-Dtech
# 3  2021       28183   Diesel      Manual      8       Honda Amaze S Diesel
# 4  2015       28451   Diesel      Manual      7       Honda City i DTEC VX

# %%
print(data.describe())
# Out:
#               Year    kms Driven         Price
# count   999.000000  9.990000e+02    999.000000
# mean   2014.717718  6.607667e+04    550.632633
# std       3.713756  5.310468e+04   6652.868796
# min    2000.000000  1.425000e+03      1.000000
# 25%    2013.000000  3.534100e+04      3.000000
# 50%    2015.000000  5.990000e+04      5.000000
# 75%    2017.000000  8.528750e+04      7.000000
# max    2023.000000  1.100000e+06  95000.000000

# %%
plt.boxplot(data['kms Driven'])
plt.title("milage wise analysis of this bullshit")
plt.ylabel("kilometer driven")
plt.show()

# %%
median_price=np.median(data['kms Driven'])
print('median_price = ',median_price)
# Out:
# median_price =  59900.0

# %%
print("\nMissing Values:")
print(data.isnull().sum())
# Out:
# Missing Values:
# Year          0
# kms Driven    0
# Fuel Type     0
# Suspension    0
# Price         0
# Car Model     0
# dtype: int64

# %%
x=data.drop('Car Model',axis=1)
y=data['Price']

print("Independent Variaables (x): ")
print(x.head())
print("dependent Variaables (y): ")
print(y.head())
# Out:
# Independent Variaables (x):
#    Year  kms Driven Fuel Type Suspension  Price
# 0  2015       81506      CNG      Manual      4
# 1  2019       23561   Diesel      Manual     11
# 2  2014       27961   Diesel      Manual      4
# 3  2021       28183   Diesel      Manual      8
# 4  2015       28451   Diesel      Manual      7
# dependent Variaables (y):
# 0     4
# 1    11
# 2     4
# 3     8
# 4     7
# Name: Price, dtype: int64

# %%
print("before encoding ")
print(data[['Suspension']].head())
# Out:
# before encoding
#    Suspension
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
data['Suspension']=le.fit_transform(data['Suspension'])

print("after encoding")
print(data.head())
# Out:
# after encoding
#    Year  kms Driven  Fuel Type  Suspension  Price                  Car Model
# 0  2015       81506          0           1      4  Honda Amaze S Plus i-VTEC
# 1  2019       23561          1           1     11     Honda BR-V i-DTEC V MT
# 2  2014       27961          1           1      4      Honda Amaze S i-Dtech
# 3  2021       28183          1           1      8       Honda Amaze S Diesel
# 4  2015       28451          1           1      7       Honda City i DTEC VX

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()

x_trainNorm = StandardScaler.fit_transform(x_train)

print("normalized data (first 5 rows): ")
print(x_trainNorm[:5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 10
#       6 from sklearn.preprocessing import MinMaxScaler
#       8 # scaler = MinMaxScaler()
# ---> 10 x_trainNorm = StandardScaler.fit_transform(x_train)
#      12 print("normalized data (first 5 rows): ")
#      13 print(x_trainNorm[:5])
#
# TypeError: TransformerMixin.fit_transform() missing 1 required positional argument: 'X'
